# %% [markdown]
# <a href="https://colab.research.google.com/github/aradhyaraina15/biometric_fusion/blob/main/biometric_fusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 a =10
print(a);
